# %%
# !pip install colabcode

# %%
from colabcode import ColabCode
ColabCode(port=10000)
# Out:
# ERROR:pyngrok.process.ngrok:t=2024-02-18T20:39:15+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session obj=csess id=452227bff192 err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ---------------------------------------------------------------------------
# PyngrokNgrokError                         Traceback (most recent call last)
# <ipython-input-9-01773564ec97> in <cell line: 2>()
#       1 from colabcode import ColabCode
# ----> 2 ColabCode(port=10000)
#
# /usr/local/lib/python3.10/dist-packages/colabcode/code.py in __init__(self, port, password, authtoken, mount_drive, code, lab)
#      42             self._install_code()
#      43             self._install_extensions()
# ---> 44             self._start_server()
#      45             self._run_code()
#      46
# ...
